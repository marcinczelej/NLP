# %%
LSTM_SIZE = 512
EMBEDDING_SIZE = 250
BATCH_SIZE= 64
EPOCHS = 20

# %%
import os
import sys
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split

sys.path.insert(0, r"../utilities")

from utils import *
from Seq2SeqTrainer import Seq2SeqTrainer

# %%
    data_dir = "../data"
    # reading data

    en_lines, fr_lines = read_data_files(data_dir, ("small_vocab_en", "small_vocab_fr"))
    """
    data = read_data(os.path.join(data_dir, "fra-eng"), "fra.txt")
    en_lines, fr_lines = list(zip(*data))
    
    en_lines = en_lines[:30000]
    fr_lines = fr_lines[:30000]
    """
    en_lines = [normalize(line) for line in en_lines]
    fr_lines = [normalize(line) for line in fr_lines]

    en_train, en_test, fr_train, fr_test = train_test_split(en_lines, fr_lines, shuffle=True, test_size=0.1)

    fr_train_in = ['<start> ' + line for line in fr_train]
    fr_train_out = [line + ' <end>' for line in fr_train]

    fr_test_in = ['<start> ' + line for line in fr_test]
    fr_test_out = [line + ' <end>' for line in fr_test]

    fr_tokenizer = Tokenizer(filters='')
    en_tokenizer = Tokenizer(filters='')

    input_data = [fr_train_in, fr_train_out, fr_test_in, fr_test_out, fr_test, fr_train]
    fr_train_in, fr_train_out, fr_test_in, fr_test_out, fr_test, fr_train = tokenizeInput(input_data,
                                                                                          fr_tokenizer)

    input_data = [en_train, en_test]
    en_train, en_test = tokenizeInput(input_data, en_tokenizer)

    en_vocab_size = len(en_tokenizer.word_index)+1
    fr_vocab_size = len(fr_tokenizer.word_index)+1
    print("en_vocab {}\nfr_vocab {}" .format(en_vocab_size, fr_vocab_size))
# Out:
# reading data from  ../data/small_vocab_en
# reading data from  ../data/small_vocab_fr
# en_vocab 203
# fr_vocab 336

# %%
trainer = Seq2SeqTrainer(BATCH_SIZE, LSTM_SIZE, EMBEDDING_SIZE, 2)

# %%
losses, accuracy= trainer.train([en_train, fr_train_in, fr_train_out], [en_test, fr_test_in, fr_test_out], [en_tokenizer, fr_tokenizer], 20, restore_checkpoint=False)
# Out:
# en_vocab 203
# fr_vocab 336
# Number of devices: 4
# creating dataset...
# dataset created
# training from scratch
# starting training with 20 epochs with prediction each 2 epoch
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# WARNING:tensorflow:Efficient allreduce is not supported for 2 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# WARNING:tensorflow:Efficient allreduce is not supported for 2 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1 training Loss 19.3414 Accuracy 0.3937  test Loss 9.6974 Accuracy 0.5246
# Saving checkpoint for epoch 0: ./checkpoints/train/ckpt-1
# --------------PREDICTION--------------
#   English   :  ['new jersey is nice during may and it is usually wonderful in january .']
#   Predicted :  new jersey est agreable en avril et il est jamais chaud en mars .
#   Correct   :  ['new jersey est agreable au mois de mai et il est generalement merveilleux en janvier . <end>']
# ------------END PREDICTION------------
# Epoch 2 training Loss 5.5896 Accuracy 0.5484  test Loss 1.9480 Accuracy 0.6644
# Epoch 3 training Loss 1.2373 Accuracy 0.6141  test Loss 0.7367 Accuracy 0.6775
# --------------PREDICTION--------------
#   English   :  ['france is never relaxing during february but it is usually wet in fall .']
#   Predicted :  la france est jamais relaxant en fevrier mais il est generalement humide a l automne .
#   Correct   :  ['la france est jamais relaxant en fevrier mais il est generalement humide a l automne . <end>']
# ------------END PREDICTION------------
# Epoch 4 training Loss 0.6491 Accuracy 0.6206  test Loss 0.4906 Accuracy 0.6805
# Epoch 5 training Loss 0.4515 Accuracy 0.6231  test Loss 0.3777 Accuracy 0.6825
# --------------PREDICTION--------------
#   English   :  ['his favorite fruit is the grapefruit but our favorite is the lime .']
#   Predicted :  son fruit prefere est le pamplemousse mais notre prefere est la chaux .
#   Correct   :  ['son fruit prefere est le pamplemousse mais notre prefere est la chaux . <end>']
# ------------END PREDICTION------------
# Epoch 6 training Loss 0.3452 Accuracy 0.6244  test Loss 0.3202 Accuracy 0.6829
# Saving checkpoint for epoch 5: ./checkpoints/train/ckpt-2
# Epoch 7 training Loss 0.2948 Accuracy 0.6249  test Loss 0.2622 Accuracy 0.6838
# --------------PREDICTION--------------
#   English   :  ['china is usually busy during january and it is rainy in summer .']
#   Predicted :  chine est generalement occupe en janvier et il pleut en ete .
#   Correct   :  ['chine est generalement occupe en janvier et il est pluvieux en ete . <end>']
# ------------END PREDICTION------------
# Epoch 8 training Loss 0.2380 Accuracy 0.6257  test Loss 0.2317 Accuracy 0.6841
# Epoch 9 training Loss 0.2052 Accuracy 0.6260  test Loss 0.2230 Accuracy 0.6842
# --------------PREDICTION--------------
#   English   :  ['the pear is their least favorite fruit but the grape is her least favorite .']
#   Predicted :  la poire est leur fruit prefere moins mais le raisin est son moins prefere .
#   Correct   :  ['la poire est leur fruit prefere moins mais le raisin est son moins prefere . <end>']
# ------------END PREDICTION------------
# Epoch 10 training Loss 0.1856 Accuracy 0.6263  test Loss 0.2202 Accuracy 0.6843
# Epoch 11 training Loss 0.1671 Accuracy 0.6265  test Loss 0.2064 Accuracy 0.6845
# Saving checkpoint for epoch 10: ./checkpoints/train/ckpt-3
# --------------PREDICTION--------------
#   English   :  ['california is sometimes freezing during april but it is snowy in autumn .']
#   Predicted :  la californie est parfois le gel en avril mais il est neigeux a l automne .
#   Correct   :  ['la californie est parfois le gel en avril mais il est neigeux a l automne . <end>']
# ------------END PREDICTION------------
# Epoch 12 training Loss 0.1557 Accuracy 0.6267  test Loss 0.1870 Accuracy 0.6850
# Epoch 13 training Loss 0.1351 Accuracy 0.6269  test Loss 0.1847 Accuracy 0.6849
# --------------PREDICTION--------------
#   English   :  ['the grapefruit is my least liked fruit but the apple is their least liked .']
#   Predicted :  le pamplemousse est mon moins aime des fruits mais la pomme est leur moins aime .
#   Correct   :  ['le pamplemousse est mon moins aime des fruits mais la pomme est leur moins aime . <end>']
# ------------END PREDICTION------------
# Epoch 14 training Loss 0.1240 Accuracy 0.6271  test Loss 0.1712 Accuracy 0.6850
# Epoch 15 training Loss 0.1162 Accuracy 0.6272  test Loss 0.1766 Accuracy 0.6852
# --------------PREDICTION--------------
#   English   :  ['the mango is your least favorite fruit but the lime is his least favorite .']
#   Predicted :  la mangue est votre fruit prefere moins mais la chaux est son moins prefere .
#   Correct   :  ['la mangue est votre fruit prefere moins mais la chaux est son moins prefere . <end>']
# ------------END PREDICTION------------
# Epoch 16 training Loss 0.1036 Accuracy 0.6273  test Loss 0.1569 Accuracy 0.6854
# Saving checkpoint for epoch 15: ./checkpoints/train/ckpt-4
# Epoch 17 training Loss 0.0984 Accuracy 0.6274  test Loss 0.1672 Accuracy 0.6852
# --------------PREDICTION--------------
#   English   :  ['my least favorite fruit is the orange but their least favorite is the mango .']
#   Predicted :  mon fruit prefere est moins l orange mais leur moins prefere est la mangue .
#   Correct   :  ['mon fruit prefere est moins l orange mais leur moins prefere est la mangue . <end>']
# ------------END PREDICTION------------
# Epoch 18 training Loss 0.0883 Accuracy 0.6276  test Loss 0.1698 Accuracy 0.6851
# Epoch 19 training Loss 0.0864 Accuracy 0.6276  test Loss 0.1556 Accuracy 0.6857
# --------------PREDICTION--------------
#   English   :  ['france is quiet during april but it is sometimes busy in summer .']
#   Predicted :  france est calme en avril mais il est parfois occupe en ete .
#   Correct   :  ['france est calme en avril mais il est parfois occupe en ete . <end>']
# ------------END PREDICTION------------
# Epoch 20 training Loss 0.0818 Accuracy 0.6277  test Loss 0.1631 Accuracy 0.6854

# %%
losses, accuracy= trainer.train([en_train, fr_train_in, fr_train_out], [en_test, fr_test_in, fr_test_out], [en_tokenizer, fr_tokenizer], 20, restore_checkpoint=True)
# Out:
# en_vocab 203
# fr_vocab 336
# Number of devices: 4
# creating dataset...
# dataset created
# Latest checkpoint restored!!
# starting training with 20 epochs with prediction each 2 epoch
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# WARNING:tensorflow:Efficient allreduce is not supported for 2 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1 training Loss 0.0938 Accuracy 0.6275  test Loss 0.1705 Accuracy 0.6852
# Saving checkpoint for epoch 0: ./checkpoints/train/ckpt-5
# --------------PREDICTION--------------
#   English   :  ['china is sometimes freezing during march and it is sometimes nice in may .']
#   Predicted :  la chine est parfois le gel en mars et il est parfois agreable en mai .
#   Correct   :  ['la chine est parfois le gel en mars et il est parfois agreable en mai . <end>']
# ------------END PREDICTION------------
# Epoch 2 training Loss 0.0944 Accuracy 0.6275  test Loss 0.1507 Accuracy 0.6856
# Epoch 3 training Loss 0.0848 Accuracy 0.6276  test Loss 0.1571 Accuracy 0.6855
# --------------PREDICTION--------------
#   English   :  ['he likes apples mangoes and bananas .']
#   Predicted :  il aime les pommes les mangues et les bananes .
#   Correct   :  ['il aime les pommes les mangues et les bananes . <end>']
# ------------END PREDICTION------------
# Epoch 4 training Loss 0.0781 Accuracy 0.6277  test Loss 0.1532 Accuracy 0.6855
# Epoch 5 training Loss 0.0683 Accuracy 0.6279  test Loss 0.1538 Accuracy 0.6855
# --------------PREDICTION--------------
#   English   :  ['they like strawberries lemons and oranges .']
#   Predicted :  ils aiment les fraises les citrons et les oranges .
#   Correct   :  ['ils aiment les fraises les citrons et les oranges . <end>']
# ------------END PREDICTION------------
# Epoch 6 training Loss 0.0649 Accuracy 0.6279  test Loss 0.1466 Accuracy 0.6856
# Saving checkpoint for epoch 5: ./checkpoints/train/ckpt-6
# Epoch 7 training Loss 0.0631 Accuracy 0.6280  test Loss 0.1524 Accuracy 0.6856
# --------------PREDICTION--------------
#   English   :  ['the united states is usually warm during october but it is usually pleasant in may .']
#   Predicted :  les etats-unis est generalement chaud au mois d octobre mais il est generalement agreable en mai .
#   Correct   :  ['les etats-unis est generalement chaud au mois d octobre mais il est generalement agreable en mai . <end>']
# ------------END PREDICTION------------
# Epoch 8 training Loss 0.0575 Accuracy 0.6280  test Loss 0.1544 Accuracy 0.6853
# Epoch 9 training Loss 0.0566 Accuracy 0.6280  test Loss 0.1611 Accuracy 0.6858
# --------------PREDICTION--------------
#   English   :  ['he might go to the united states next november .']
#   Predicted :  il pourrait aller aux etats-unis en novembre prochain .
#   Correct   :  ['il pourrait aller aux etats-unis en novembre prochain . <end>']
# ------------END PREDICTION------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e24e17be2099> in <module>
# ----> 1 losses, accuracy= trainer.train([en_train, fr_train_in, fr_train_out], [en_test, fr_test_in, fr_test_out], [en_tokenizer, fr_tokenizer], 20, restore_checkpoint=True)
#
# /shared/NLP/Seq2Seq/Seq2SeqTrainer.py in train(self, train_dataset_data, test_dataset_data, tokenizers, epochs, restore_checkpoint)
#     156                 num_batches = 0
#     157                 for _, (en_data, fr_data_in, fr_data_out) in enumerate(train_dataset_distr):
# --> 158                     loss = distributed_train_step(en_data, fr_data_in, fr_data_out, initial_state)
#     159                     total_loss += loss
#     160                     num_batches += 1
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
